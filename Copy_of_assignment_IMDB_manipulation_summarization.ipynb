# %% [markdown]
# <a href="https://colab.research.google.com/github/garrick-watkins/MIS-433/blob/main/Copy_of_assignment_IMDB_manipulation_summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment - Analyzing the IMDB Top 1000 Movies

# %% [markdown]
# In the next few assignments, you will be working with this data set of IMDB top 1000 movies.
#
# Source: https://www.kaggle.com/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# To read the data file from your Google Drive, mount your drive first.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read the data file "imdb_top_1000.csv" to a dataframe named "imdb"
imdb = pd.read_csv('/content/drive/MyDrive/MIS 433/imdb_top_1000.csv', header=0)
imdb.head(20)
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8   https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9   https://m.media-amazon.com/images/M/MV5BMmEzNT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 11  https://m.media-amazon.com/images/M/MV5BNWIwOD...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
# 13  https://m.media-amazon.com/images/M/MV5BZGMxZT...
# 14  https://m.media-amazon.com/images/M/MV5BNzQzOT...
# 15  https://m.media-amazon.com/images/M/MV5BY2NkZj...
# 16  https://m.media-amazon.com/images/M/MV5BYmU1ND...
# 17  https://m.media-amazon.com/images/M/MV5BZjA0OW...
# 18  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 19  https://m.media-amazon.com/images/M/MV5BYWZjMj...
#
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 1                                       The Godfather          1972
# 2                                     The Dark Knight          2008
# 3                              The Godfather: Part II          1974
# 4                                        12 Angry Men          1957
# 5       The Lord of the Rings: The Return of the King          2003
# 6                                        Pulp Fiction          1994
# 7                                    Schindler's List          1993
# 8                                           Inception          2010
# 9                                          Fight Club          1999
# 10  The Lord of the Rings: The Fellowship of the Ring          2001
# 11                                       Forrest Gump          1994
# 12                    Il buono, il brutto, il cattivo          1966
# 13              The Lord of the Rings: The Two Towers          2002
# 14                                         The Matrix          1999
# 15                                         Goodfellas          1990
# 16     Star Wars: Episode V - The Empire Strikes Back          1980
# 17                    One Flew Over the Cuckoo's Nest          1975
# 18                                           Hamilton          2020
# 19                                       Gisaengchung          2019
#
#    Certificate  Runtime                       Genre  IMDB_Rating  \
# 0            A  142 min                       Drama          9.3
# 1            A  175 min                Crime, Drama          9.2
# 2           UA  152 min        Action, Crime, Drama          9.0
# 3            A  202 min                Crime, Drama          9.0
# 4            U   96 min                Crime, Drama          9.0
# 5            U  201 min    Action, Adventure, Drama          8.9
# 6            A  154 min                Crime, Drama          8.9
# 7            A  195 min   Biography, Drama, History          8.9
# 8           UA  148 min   Action, Adventure, Sci-Fi          8.8
# 9            A  139 min                       Drama          8.8
# 10           U  178 min    Action, Adventure, Drama          8.8
# 5         Ian McKellen           Orlando Bloom      1642758  377,845,905
# 6    Samuel L. Jackson            Bruce Willis      1826188  107,928,762
# 7         Ben Kingsley        Caroline Goodall      1213505   96,898,818
# 8          Elliot Page            Ken Watanabe      2067042  292,576,195
# 9            Meat Loaf            Zach Grenier      1854740   37,030,102
# 10       Orlando Bloom               Sean Bean      1661481  315,544,750
# 11         Gary Sinise             Sally Field      1809221  330,252,182
# 12       Lee Van Cleef            Aldo Giuffrè       688390    6,100,000
# 13     Viggo Mortensen           Orlando Bloom      1485555  342,551,365
# 14  Laurence Fishburne        Carrie-Anne Moss      1676426  171,479,930
# 15           Joe Pesci         Lorraine Bracco      1020727   46,836,394
# 16       Carrie Fisher      Billy Dee Williams      1159315  290,475,067
# 17    Michael Berryman            Peter Brocco       918088  112,000,000
# 18     Leslie Odom Jr.  Renée Elise Goldsberry        55291          NaN
# 19       Cho Yeo-jeong            Choi Woo-sik       552778   53,367,844

# %%
# Describe the dataframe using the info() method.
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
# List all the column names:
imdb.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# ## Part 1: Data Manipulation

# %%
# Display top 10 movies' title, released year and IMDB rating.
imdb[['Series_Title', 'Released_Year', 'IMDB_Rating']].head(10)
# Out:
#                                     Series_Title Released_Year  IMDB_Rating
# 0                       The Shawshank Redemption          1994          9.3
# 1                                  The Godfather          1972          9.2
# 2                                The Dark Knight          2008          9.0
# 3                         The Godfather: Part II          1974          9.0
# 4                                   12 Angry Men          1957          9.0
# 5  The Lord of the Rings: The Return of the King          2003          8.9
# 6                                   Pulp Fiction          1994          8.9
# 7                               Schindler's List          1993          8.9
# 8                                      Inception          2010          8.8
# 9                                     Fight Club          1999          8.8

# %%
# Display movies ranked 11-20.
# Show their title, released year and IMDB rating.
imdb[['Series_Title', 'Released_Year', 'IMDB_Rating']].iloc[11:20]
# Out:
#                                       Series_Title Released_Year  IMDB_Rating
# 11                                    Forrest Gump          1994          8.8
# 12                 Il buono, il brutto, il cattivo          1966          8.8
# 13           The Lord of the Rings: The Two Towers          2002          8.7
# 14                                      The Matrix          1999          8.7
# 15                                      Goodfellas          1990          8.7
# 16  Star Wars: Episode V - The Empire Strikes Back          1980          8.7
# 17                 One Flew Over the Cuckoo's Nest          1975          8.7
# 18                                        Hamilton          2020          8.6
# 19                                    Gisaengchung          2019          8.6

# %%
# Select all movies directed by Quentin Tarantino.
# Show their title, released year, IMDB rating, and gross.
imdb[imdb['Director'] == 'Quentin Tarantino'][['Series_Title', 'Released_Year', 'IMDB_Rating', 'Gross']]
# Out:
#                          Series_Title Released_Year  IMDB_Rating        Gross
# 6                        Pulp Fiction          1994          8.9  107,928,762
# 62                   Django Unchained          2012          8.4  162,805,434
# 93               Inglourious Basterds          2009          8.3  120,540,719
# 103                    Reservoir Dogs          1992          8.3    2,832,029
# 241                 Kill Bill: Vol. 1          2003          8.1   70,099,045
# 369                 Kill Bill: Vol. 2          2004          8.0   66,208,183
# 584                 The Hateful Eight          2015          7.8   54,117,416
# 879  Once Upon a Time... in Hollywood          2019          7.6  142,502,728

# %%
# Select all R rated movies with IMDB_Rating>=8.5
# Show their title, released year, certificate, and IMDB rating.
imdb[(imdb['Certificate'] == 'R') & (imdb['IMDB_Rating'] >= 8.5)][['Series_Title', 'Released_Year', 'Certificate', 'IMDB_Rating']]
# Out:
#            Series_Title Released_Year Certificate  IMDB_Rating
# 24  Saving Private Ryan          1998           R          8.6
# 38          The Pianist          2002           R          8.5
# 40   American History X          1998           R          8.5

# %%
# How many unique values are there in the column "Released_Year"?
# Hint: nunique()
imdb['Released_Year'].nunique()
# Out:
# 100

# %%
# Count the number of movies in each "Released_Year"?
# Hint: value_counts()
imdb['Released_Year'].value_counts()
# Out:
# Released_Year
# 2014    32
# 2004    31
# 2009    29
# 2013    28
# 2016    28
#         ..
# 1920     1
# 1930     1
# 1922     1
# 1943     1
# PG       1
# Name: count, Length: 100, dtype: int64

# %%
# In this dataset, there is a movie with an error in "Released_Year".
# Hint: Released_Year should be a 4-digit integer but this movie's is not.
# Find this movie.
error_movie = imdb[imdb['Released_Year'].str.len() != 4]
error_movie
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966            PG           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
# Correct the values for the corresponding columns ("Released_Year" and "Certificate").
# You may want to look up this movie on www.imdb.com.
# Hint: You can set value for a particular row by: df.loc[row_name, column_name] = new_value
imdb.loc[error_movie.index[0], 'Released_Year'] = 1995

# %%
# Change the data type of "Released_Year" to int
imdb['Released_Year'] = imdb['Released_Year'].astype(int)

# %%
# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, certificate, and IMDB rating.
imdb[(imdb['Released_Year'] >= 2010) & (imdb['IMDB_Rating'] >= 8.5)][['Series_Title', 'Released_Year', 'Certificate', 'IMDB_Rating']]
# Out:
#         Series_Title  Released_Year Certificate  IMDB_Rating
# 8          Inception           2010          UA          8.8
# 18          Hamilton           2020       PG-13          8.6
# 19      Gisaengchung           2019           A          8.6
# 20   Soorarai Pottru           2020           U          8.6
# 21      Interstellar           2014          UA          8.6
# 33             Joker           2019           A          8.5
# 34          Whiplash           2014           A          8.5
# 35  The Intouchables           2011          UA          8.5

# %%
# Select all movies whose genres contain 'Animation'
imdb[imdb['Genre'].str.contains('Animation')]
# Out:
#                                            Poster_Link  \
# 23   https://m.media-amazon.com/images/M/MV5BMjlmZm...
# 43   https://m.media-amazon.com/images/M/MV5BYTYxNG...
# 46   https://m.media-amazon.com/images/M/MV5BZmY2Nj...
# 56   https://m.media-amazon.com/images/M/MV5BODRmZD...
# 58   https://m.media-amazon.com/images/M/MV5BMjMwND...
# ..                                                 ...
# 956  https://m.media-amazon.com/images/M/MV5BODkxNG...
# 971  https://m.media-amazon.com/images/M/MV5BMTY5Nj...
# 976  https://m.media-amazon.com/images/M/MV5BN2JlZT...
# 986  https://m.media-amazon.com/images/M/MV5BMzZiOD...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
#
#                           Series_Title  Released_Year Certificate  Runtime  \
# 23       Sen to Chihiro no kamikakushi           2001           U  125 min
# 43                       The Lion King           1994           U   88 min
# 46                      Hotaru no haka           1988           U   89 min
# 56                      Kimi no na wa.           2016           U  106 min
# 58   Spider-Man: Into the Spider-Verse           2018           U  117 min
# ..                                 ...            ...         ...      ...
# 956                              Mulan           1998           U   88 min
# 971                  Omohide poro poro           1991           U  118 min
# 976                 The Little Mermaid           1989           U   83 min
# 986                     Watership Down           1978           U   91 min
# 992                    The Jungle Book           1967           U   78 min
#
#                             Genre  IMDB_Rating  \
# 23   Animation, Adventure, Family          8.6
# 43    Animation, Adventure, Drama          8.5
# 46          Animation, Drama, War          8.5
# 56      Animation, Drama, Fantasy          8.4
# 58   Animation, Action, Adventure          8.4
# ..                            ...          ...
# 956  Animation, Adventure, Family          7.6
# 971     Animation, Drama, Romance          7.6
# 976    Animation, Family, Fantasy          7.6
# 986   Animation, Adventure, Drama          7.6
# 992  Animation, Adventure, Family          7.6
#
#                                               Overview  Meta_score  \
# 23   During her family's move to the suburbs, a sul...        96.0
# 43   Lion prince Simba and his father are targeted ...        88.0
# 46   A young boy and his little sister struggle to ...        94.0
# 56   Two strangers find themselves linked in a biza...        79.0
# 58   Teen Miles Morales becomes the Spider-Man of h...        87.0
# ..                                                 ...         ...
# 956  To save her father from death in the army, a y...        71.0
# 971  A twenty-seven-year-old office worker travels ...        90.0
# 976  A mermaid princess makes a Faustian bargain in...        88.0
# 986  Hoping to escape destruction by human develope...        64.0
# 992  Bagheera the Panther and Baloo the Bear have a...        65.0
#
#                 Director             Star1               Star2  \
# 23        Hayao Miyazaki     Daveigh Chase   Suzanne Pleshette
# 43          Roger Allers       Rob Minkoff   Matthew Broderick
# 46         Isao Takahata   Tsutomu Tatsumi     Ayano Shiraishi
# 56        Makoto Shinkai  Ryûnosuke Kamiki  Mone Kamishiraishi
# 58       Bob Persichetti      Peter Ramsey      Rodney Rothman
# ..                   ...               ...                 ...
# 956        Tony Bancroft        Barry Cook         Ming-Na Wen
# 971        Isao Takahata         Miki Imai    Toshirô Yanagiba
# 976         Ron Clements       John Musker         Jodi Benson
# 986         Martin Rosen       John Hubley           John Hurt
# 992  Wolfgang Reitherman       Phil Harris     Sebastian Cabot
#
#                 Star3              Star4  No_of_Votes        Gross
# 23         Miyu Irino       Rumi Hiiragi       651376   10,055,859
# 43       Jeremy Irons   James Earl Jones       942045  422,783,777
# 46    Akemi Yamaguchi  Yoshiko Shinohara       235231          NaN
# 56         Ryô Narita           Aoi Yûki       194838    5,017,246
# 58      Shameik Moore       Jake Johnson       375110  190,241,310
# ..                ...                ...          ...          ...
# 956      Eddie Murphy            BD Wong       256906  120,620,254
# 971        Yoko Honna       Mayumi Izuka        27071      453,243
# 976  Samuel E. Wright   Rene Auberjonois       237696  111,543,479
# 986    Richard Briers   Ralph Richardson        33656          NaN
# 992       Louis Prima   Bruce Reitherman       166409  141,843,612
#
# [82 rows x 16 columns]

# %%
# Create a new dataframe called "stars" including the following columns:
# Series_Title, Released_Year, Star1, Star2, Star3, Star4
stars = imdb[['Series_Title', 'Released_Year', 'Star1', 'Star2', 'Star3', 'Star4']]

# %%
# Create a new dataframe called "genres" including the following columns:
# Series_Title, Released_Year, Genre.
genres = imdb[['Series_Title', 'Released_Year', 'Genre']]

# %%
# Sorting:
# Sort dataframe genres in ascending order of "Released_Year"
genres.sort_values(by='Released_Year', ascending=True)
# Out:
#                      Series_Title  Released_Year                         Genre
# 321  Das Cabinet des Dr. Caligari           1920      Fantasy, Horror, Mystery
# 127                       The Kid           1921         Comedy, Drama, Family
# 568                     Nosferatu           1922               Fantasy, Horror
# 194                  Sherlock Jr.           1924       Action, Comedy, Romance
# 193                 The Gold Rush           1925      Adventure, Comedy, Drama
# ..                            ...            ...                           ...
# 612    The Trial of the Chicago 7           2020      Drama, History, Thriller
# 613                          Druk           2020                 Comedy, Drama
# 20                Soorarai Pottru           2020                         Drama
# 18                       Hamilton           2020     Biography, Drama, History
# 205                          Soul           2020  Animation, Adventure, Comedy
#
# [1000 rows x 3 columns]

# %%
# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, Certificate, and gross.
# Sort them in descending order of "Gross"
(imdb[(imdb['Released_Year'] >= 2010) & (imdb['IMDB_Rating'] >= 8.5)]
  [['Series_Title', 'Released_Year', 'Certificate', 'Gross']]
  .sort_values(by='Gross', ascending=False)
)
# Out:
#         Series_Title  Released_Year Certificate        Gross
# 19      Gisaengchung           2019           A   53,367,844
# 33             Joker           2019           A  335,451,311
# 8          Inception           2010          UA  292,576,195
# 21      Interstellar           2014          UA  188,020,017
# 35  The Intouchables           2011          UA   13,182,281
# 34          Whiplash           2014           A   13,092,000
# 18          Hamilton           2020       PG-13          NaN
# 20   Soorarai Pottru           2020           U          NaN

# %%
# Does the sorting result look right to you? What's the problem?
#18 and 20 do not have a gross

# %%
# Resolve this problem of "Gross" and convert its data type to float
# Hint: You may find this webpage useful:
# https://stackoverflow.com/questions/28986489/how-to-replace-text-in-a-column-of-a-pandas-dataframe
imdb['Gross'] = imdb['Gross'].str.replace(',', '').astype(float)

# %%
# Next, redo the sorting on Gross
(imdb[(imdb['Released_Year'] >= 2010) & (imdb['IMDB_Rating'] >= 8.5)]
  [['Series_Title', 'Released_Year', 'Certificate', 'Gross']]
  .sort_values(by='Gross', ascending=False)
)
# Select all movies released after (>=) 2010 and with IMDB_Rating>=8.5
# Show their title, released year, Certificate, and gross.
# Sort them in descending order of "Gross"
# Out:
#         Series_Title  Released_Year Certificate        Gross
# 33             Joker           2019           A  335451311.0
# 8          Inception           2010          UA  292576195.0
# 21      Interstellar           2014          UA  188020017.0
# 19      Gisaengchung           2019           A   53367844.0
# 35  The Intouchables           2011          UA   13182281.0
# 34          Whiplash           2014           A   13092000.0
# 18          Hamilton           2020       PG-13          NaN
# 20   Soorarai Pottru           2020           U          NaN

# %%
# Add a new column "Runtime_min" by removing the substring " min" in "Runtime"
# Set its data type as int
# Hint: https://stackoverflow.com/questions/36505847/substring-of-an-entire-column-in-pandas-dataframe
imdb['Runtime_min'] = imdb['Runtime'].str.replace(' min', '').astype(int)
imdb['Runtime_min']
# Out:
# 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#       ...
# 995    115
# 996    201
# 997    118
# 998     97
# 999     86
# Name: Runtime_min, Length: 1000, dtype: int64

# %%
# Add a new column "Age_Year" by expression: Current year - Released_Year
imdb['Age_Year'] = 2026 - imdb['Released_Year']
imdb['Age_Year']
# Out:
# 0      32
# 1      54
# 2      18
# 3      52
# 4      69
#        ..
# 995    65
# 996    70
# 997    73
# 998    82
# 999    91
# Name: Age_Year, Length: 1000, dtype: int64

# %%
# Add a new column "Decade" with values as 1980, 1990, 2000, 2010, 2020, etc.
imdb['Decade'] = (imdb['Released_Year'] // 10) * 10
imdb['Decade']
# Out:
# 0      1990
# 1      1970
# 2      2000
# 3      1970
# 4      1950
#        ...
# 995    1960
# 996    1950
# 997    1950
# 998    1940
# 999    1930
# Name: Decade, Length: 1000, dtype: int64

# %% [markdown]
# ## Part 2: Data Summarization

# %%
# Total "Gross" of all top 1000 movies
imdb['Gross'].sum()
# Out:
# np.float64(56536877976.0)

# %%
# Average "No_of_Votes" of all movies
imdb['No_of_Votes'].mean()
# Out:
# np.float64(273692.911)

# %%
# Count movies in each decade (e.g., ..., 1980, 1990, 2000, 2010, 2020)
# Sort decades by the number of movies in descending order
imdb['Decade'].value_counts().sort_index(ascending=False)
# Out:
# Decade
# 2010    225
# 2000    241
# 1990    162
# 1980     89
# Name: count, dtype: int64

# %%
# Count movies by different directors.
# Show the top 10 directors with the most movies in this list
imdb['Director'].value_counts().head(10)
# Out:
# Director
# Alfred Hitchcock     14
# Steven Spielberg     13
# Hayao Miyazaki       11
# Akira Kurosawa       10
# Martin Scorsese      10
# Woody Allen           9
# Stanley Kubrick       9
# Billy Wilder          9
# Clint Eastwood        8
# Christopher Nolan     8
# Name: count, dtype: int64

# %%
# For each director, calculate the number of movies, average IMDB_Rating, and total gross.
# Ranked in descending order of total gross
# Show the top 10 directors with the most gross
imdb.groupby('Director').agg({'Series_Title': 'count', 'IMDB_Rating': 'mean', 'Gross': 'sum'}).sort_values(by='Gross', ascending=False).head(10)
# Out:
#                    Series_Title  IMDB_Rating         Gross
# Director
# Steven Spielberg             13     8.030769  2.478133e+09
# Anthony Russo                 4     8.075000  2.205039e+09
# Christopher Nolan             8     8.462500  1.937454e+09
# James Cameron                 5     8.080000  1.748237e+09
# Peter Jackson                 5     8.400000  1.597312e+09
# J.J. Abrams                   3     7.833333  1.423171e+09
# Brad Bird                     4     7.900000  1.099628e+09
# Robert Zemeckis               5     8.120000  1.049446e+09
# David Yates                   3     7.800000  9.789537e+08
# Pete Docter                   4     8.125000  9.393821e+08

# %%
# Group movies by decade and director
# In each group (i.e., for each decade and each director),
# calculate the number of movies and average IMDB rating.
# Sort in descending order of movie count
imdb.groupby(['Decade', 'Director']).agg({'Series_Title': 'count', 'IMDB_Rating': 'mean'}).sort_values(by='Series_Title', ascending=False)
# Out:
# /tmp/ipykernel_491/3665860440.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   imdb.groupby(['Decade', 'Director']).agg({'Series_Title': 'count', 'IMDB_Rating': 'mean'}).sort_values(by='Series_Title', ascending=False)
#                               Series_Title  IMDB_Rating
# Decade Director
# 1980   Rob Reiner                        5         7.88
#        Steven Spielberg                  5         7.98
# 2000   Clint Eastwood                    5         7.94
# 1990   Joel Coen                         4         7.90
# 2010   Denis Villeneuve                  4         7.90
# ...                                    ...          ...
# 1980   Aditya Dhar                       0          NaN
#        Alain Resnais                     0          NaN
#        Alan J. Pakula                    0          NaN
#        Alejandro Amenábar                0          NaN
#        Alejandro G. Iñárritu             0          NaN
#
# [2192 rows x 2 columns]

# %%
# Find the top 3 highest rated movies of each year since 2010.
# Show their released year, ranking, title, and IMDB_Rating.
# Sort them in descending order of year and ascending order of ranking
imdb[imdb['Released_Year'] >= 2010].sort_values(by=['Released_Year', 'IMDB_Rating'], ascending=[False, False]).groupby('Released_Year').head(3)
# Out:
#                                            Poster_Link  \
# 18   https://m.media-amazon.com/images/M/MV5BNjViNW...
# 20   https://m.media-amazon.com/images/M/MV5BOTc2ZT...
# 205  https://m.media-amazon.com/images/M/MV5BZGE1MD...
# 19   https://m.media-amazon.com/images/M/MV5BYWZjMj...
# 33   https://m.media-amazon.com/images/M/MV5BNGVjNW...
# 59   https://m.media-amazon.com/images/M/MV5BMTc5MD...
# 53   https://m.media-amazon.com/images/M/MV5BMmExNz...
# 58   https://m.media-amazon.com/images/M/MV5BMjMwND...
# 60   https://m.media-amazon.com/images/M/MV5BMjMxNj...
# 54   https://m.media-amazon.com/images/M/MV5BNWJhMD...
# 55   https://m.media-amazon.com/images/M/MV5BY2FiMT...
# 61   https://m.media-amazon.com/images/M/MV5BYjQ5Nj...
# 56   https://m.media-amazon.com/images/M/MV5BODRmZD...
# 57   https://m.media-amazon.com/images/M/MV5BMTQ4Mz...
# 54      Biography, Drama, History          8.4
# 55           Action, Crime, Drama          8.4
# 61   Animation, Adventure, Family          8.4
# 56      Animation, Drama, Fantasy          8.4
# 57       Action, Biography, Drama          8.4
# 196               Drama, Thriller          8.1
# 133         Crime, Drama, Mystery          8.2
# 136         Crime, Drama, Mystery          8.2
# 203               Drama, Thriller          8.1
# 21       Adventure, Drama, Sci-Fi          8.6
# 34                   Drama, Music          8.5
# 200                         Drama          8.1
# 87         Crime, Drama, Thriller          8.3
# 137      Adventure, Comedy, Drama          8.2
# 138                    Drama, War          8.2
# 62                 Drama, Western          8.4
# 63              Action, Adventure          8.4
# 88                          Drama          8.3
# 35       Biography, Comedy, Drama          8.5
# 89                          Drama          8.3
# 144          Action, Drama, Sport          8.2
# 8       Action, Adventure, Sci-Fi          8.8
# 90            Drama, Mystery, War          8.3
# 141                         Drama          8.2
#
#                                               Overview  Meta_score  \
# 18   The real life of one of America's foremost fou...        90.0
# 20   Nedumaaran Rajangam "Maara" sets out to make t...         NaN
# 205  After landing the gig of a lifetime, a New Yor...        83.0
# 19   Greed and class discrimination threaten the ne...        96.0
# 33   In Gotham City, mentally troubled comedian Art...        59.0
# 59   After the devastating events of Avengers: Infi...        78.0
# 53   While serving a five-year sentence for a viole...        75.0
# 58   Teen Miles Morales becomes the Spider-Man of h...        87.0
# 60   The Avengers and their allies must be willing ...        68.0
# 54   In 1950, amid-st the ravages of the Korean War...         NaN
# 55   Vikram, a no-nonsense police officer, accompan...         NaN
# 61   Aspiring musician Miguel, confronted with his ...        81.0
# 56   Two strangers find themselves linked in a biza...        79.0
# 57   Former wrestler Mahavir Singh Phogat and his t...         NaN
# 196  When three young women are implicated in a cri...         NaN
# 133  An experienced investigator confronts several ...         NaN
# 136  Desperate measures are taken by a man who trie...         NaN
# 203  Held captive for 7 years in an enclosed space,...        86.0
# 21   A team of explorers travel through a wormhole ...        74.0
# 34   A promising young drummer enrolls at a cut-thr...        88.0
# 200  A widowed single mother, raising her violent s...        74.0
# 87   A man goes to extreme lengths to save his fami...         NaN
# 137  A Delhi girl from a traditional family sets ou...         NaN
# 138  In 1992, war rages in Abkhazia, a breakaway re...        73.0
# 62   With the help of a German bounty hunter, a fre...        81.0
# 63   Eight years after the Joker's reign of anarchy...        78.0
# 88   A teacher lives a lonely life, all the while s...        77.0
# 35   After he becomes a quadriplegic from a paragli...        57.0
# 89   A married couple are faced with a difficult de...        95.0
# 144  The youngest son of an alcoholic former boxer ...        71.0
# 8    A thief who steals corporate secrets through t...        74.0
# 90   Twins journey to the Middle East to discover t...        80.0
# 141  Expelled from his school, a 16-year old boy re...         NaN
#
#                     Director                Star1                      Star2  \
# 18               Thomas Kail   Lin-Manuel Miranda               Phillipa Soo
# 20             Sudha Kongara               Suriya                   Madhavan
# 205              Pete Docter          Kemp Powers                 Jamie Foxx
# 19              Bong Joon Ho         Kang-ho Song               Lee Sun-kyun
# 33             Todd Phillips      Joaquin Phoenix             Robert De Niro
# 59             Anthony Russo            Joe Russo          Robert Downey Jr.
# 53             Nadine Labaki       Zain Al Rafeea          Yordanos Shiferaw
# 63                 Anne Hathaway             Gary Oldman      1516346
# 88             Annika Wedderkopp        Lasse Fogelstrøm       281623
# 35                       Omar Sy              Anne Le Ny       760360
# 89                   Sareh Bayat         Shahab Hosseini       220002
# 144                Joel Edgerton       Jennifer Morrison       435950
# 8                    Elliot Page            Ken Watanabe      2067042
# 90                Maxim Gaudette           Mustafa Kamel       150023
# 141                 Manjot Singh              Ram Kapoor        42341
#
#            Gross  Runtime_min  Age_Year Decade
# 18           NaN          160         6   2010
# 20           NaN          153         6   2010
# 205          NaN          100         6   2010
# 19    53367844.0          132         7   2010
# 33   335451311.0          122         7   2010
# 59   858373000.0          181         7   2010
# 53     1661096.0          126         8   2010
# 58   190241310.0          117         8   2010
# 60   678815482.0          149         8   2010
# 54           NaN          125         9   2010
# 55           NaN          147         9   2010
# 61   209726015.0          105         9   2010
# 56     5017246.0          106        10   2010
# 57    12391761.0          161        10   2010
# 196    1241223.0          136        10   2010
# 133     342370.0          132        11   2010
# 136     739478.0          163        11   2010
# 203   14677674.0          118        11   2010
# 21   188020017.0          169        12   2010
# 34    13092000.0          106        12   2010
# 200    3492754.0          139        12   2010
# 87           NaN          160        13   2010
# 137    1429534.0          146        13   2010
# 138     144501.0           87        13   2010
# 62   162805434.0          165        14   2010
# 63   448139099.0          164        14   2010
# 88      687185.0          115        14   2010
# 35    13182281.0          112        15   2010
# 89     7098492.0          123        15   2010
# 144   13657115.0          140        15   2010
# 8    292576195.0          148        16   2000
# 90     6857096.0          131        16   2000
# 141       7461.0          134        16   2000

# %%
# Find all directors whose movies appeared in at least five different decades.
# Your result should include: director, decade, and the number of movies in the decade.
# 1. Group by Director and Decade to get the count of movies.
director_decades = imdb.groupby(['Director', 'Decade']).size().reset_index(name='Movie_Count')
result = director_decades[director_decades.groupby('Director')['Decade'].transform('count') >= 5]
result = result.sort_values(by=['Director', 'Decade'])

result
# Out:
#              Director  Decade  Movie_Count
# 247    Hayao Miyazaki    1970            1
# 248    Hayao Miyazaki    1980            4
# 249    Hayao Miyazaki    1990            2
# 250    Hayao Miyazaki    2000            3
# 251    Hayao Miyazaki    2010            1
# 424   Martin Scorsese    1970            1
# 425   Martin Scorsese    1980            3
# 426   Martin Scorsese    1990            2
# 427   Martin Scorsese    2000            1
# 428   Martin Scorsese    2010            3
# 644  Steven Spielberg    1970            2
# 645  Steven Spielberg    1980            5
# 646  Steven Spielberg    1990            3
# 647  Steven Spielberg    2000            2
# 648  Steven Spielberg    2010            1

# %%
# Ask two questions about this dataset and write your code to answer them.
# Question 1:
top_actors = imdb['Star1'].value_counts().head(5)
top_actors
# Out:
# Star1
# Tom Hanks          12
# Robert De Niro     11
# Al Pacino          10
# Clint Eastwood     10
# Humphrey Bogart     9
# Name: count, dtype: int64

# %%
# Questions 2:
best_decades = imdb.groupby('Decade')['IMDB_Rating'].mean().sort_values(ascending=False)
best_decades.head()
# Out:
# Decade
# 2020    8.133333
# 1920    8.127273
# 1950    8.058929
# 1940    8.025714
# 1960    7.973973
# Name: IMDB_Rating, dtype: float64
